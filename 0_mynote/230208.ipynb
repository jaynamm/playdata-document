# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = np.arange(5)
data2 = np.arange(2, 6)

# %%
for i in range(1, 10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
fig, axs = plt.subplots(2, 2, figsize=[15, 5])

# axs.shape[0] == 2
for x in range(axs.shape[0]): # range(2) => 0, 1
#     print("x 시작")
#     print("x = ", x)
    
#     # axs.shape[1] == 2
    for y in range(axs.shape[1]): # range(2) => 0, 1
        print("x, y = ", x, y)
        axs[x,y].plot(data1)
        
        if x == 0 and y == 1:
            print("x, y = ", x, y)
            axs[x,y].plot(data2)
#         print("y 시작")
#         print("y = ", y)
        
#         print("x = ", x ," / y = ", y)
#         print()
#     print("y 끝")
#     print()
# print("x 끝")
# print()
# Out:
# x, y =  0 0
# x, y =  0 1
# x, y =  0 1
# x, y =  1 0
# x, y =  1 1

# %%
for x in range(2, 10): # 2~9
    for y in range(1, 10): #1~9
        print(x, y, " = ", x*y)
# Out:
# 2 1  =  2
# 2 2  =  4
# 2 3  =  6
# 2 4  =  8
# 2 5  =  10
# 2 6  =  12
# 2 7  =  14
# 2 8  =  16
# 2 9  =  18
# 3 1  =  3
# 3 2  =  6
# 3 3  =  9
# 3 4  =  12
# 3 5  =  15
# 3 6  =  18
# 3 7  =  21
# 3 8  =  24
# 3 9  =  27
# 4 1  =  4
# 4 2  =  8
# 4 3  =  12
# 4 4  =  16
# 4 5  =  20
# 4 6  =  24
# 4 7  =  28
# 4 8  =  32
# 4 9  =  36
# 5 1  =  5
# 5 2  =  10
# 5 3  =  15
# 5 4  =  20
# 5 5  =  25
# 5 6  =  30
# 5 7  =  35
# 5 8  =  40
# 5 9  =  45
# 6 1  =  6
# 6 2  =  12
# 6 3  =  18
# 6 4  =  24
# 6 5  =  30
# 6 6  =  36
# 6 7  =  42
# 6 8  =  48
# 6 9  =  54
# 7 1  =  7
# 7 2  =  14
# 7 3  =  21
# 7 4  =  28
# 7 5  =  35
# 7 6  =  42
# 7 7  =  49
# 7 8  =  56
# 7 9  =  63
# 8 1  =  8
# 8 2  =  16
# 8 3  =  24
# 8 4  =  32
# 8 5  =  40
# 8 6  =  48
# 8 7  =  56
# 8 8  =  64
# 8 9  =  72
# 9 1  =  9
# 9 2  =  18
# 9 3  =  27
# 9 4  =  36
# 9 5  =  45
# 9 6  =  54
# 9 7  =  63
# 9 8  =  72
# 9 9  =  81

# %%
fig, axs = plt.subplots(2, 2, figsize=[15, 5])

for x in range(axs.shape[0]):
    # 1. x == 0
    for y in range(axs.shape[1]):
        # 2. y == 0
        
        # 3. x = 0, y = 0
        # axs[0,0].plot(data1)
        axs[x,y].plot(data1)        # 실행
        
        if x == 0 and y == 1:
            axs[x,y].plot(data2)

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=[15, 5])

# for i, ax in enumerate(axs):
#     print(i, ax)
#     ax[0].plot(data1)
#     ax[1].plot(data1)
#     print(bool(i))
#     if not i-1:
#         ax[1].plot(data2)


for i, ax in enumerate(axs):
    print("start")
    print(i, ax)
    ax[0].plot(data1)
    ax[1].plot(data1)
    print("end")
    
    if not i: # i == True, 1 or i == False, 0 (boolean)
        ax[1].plot(data2) # i = 0, ax = 1 -> axs[0,1]
# Out:
# start
# 0 [<AxesSubplot:> <AxesSubplot:>]
# end
# start
# 1 [<AxesSubplot:> <AxesSubplot:>]
# end

# %%
fig, axs = plt.subplots(2, 2, figsize=[15, 5])

axs[1]
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
a = [
    [1, 2], 
    [3, 4]
]

a[0] = [1, 2]
a[1] = [3, 4]

# %%
fig, axs = plt.subplots(2, 2, figsize=[15, 5])

for i, ax in enumerate(axs):
#   0 :  [<AxesSubplot:>, <AxesSubplot:>]
    print(i, ax)
    ax[0].plot(data1)
    ax[1].plot(data1)
    
    if not i: # True 1 / False 0
        ax[1].plot(data2)


# 00 01
# 10 11
# Out:
# 0 [<AxesSubplot:> <AxesSubplot:>]
# 1 [<AxesSubplot:> <AxesSubplot:>]
