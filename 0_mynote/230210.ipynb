# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# # 컬럼명 소문자 변환

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# 컬럼만 변경
# df.columns = ['age', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone']

# 컬럼 순서 변경
df = df[['age', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
       'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
       'alive', 'alone']]

df
# Out:
#       age  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0    22.0       3    male  22.0      1      0   7.2500        S   Third
# 1    38.0       1  female  38.0      1      0  71.2833        C   First
# 2    26.0       3  female  26.0      0      0   7.9250        S   Third
# 3    35.0       1  female  35.0      1      0  53.1000        S   First
# 4    35.0       3    male  35.0      0      0   8.0500        S   Third
# ..    ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886  27.0       2    male  27.0      0      0  13.0000        S  Second
# 887  19.0       1  female  19.0      0      0  30.0000        S   First
# 888   NaN       3  female   NaN      1      2  23.4500        S   Third
# 889  26.0       1    male  26.0      0      0  30.0000        C   First
# 890  32.0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns = [c.upper() for c in df.columns]

# %%
df
# Out:
#       AGE  PCLASS     SEX   AGE  SIBSP  PARCH     FARE EMBARKED   CLASS  \
# 0    22.0       3    male  22.0      1      0   7.2500        S   Third
# 1    38.0       1  female  38.0      1      0  71.2833        C   First
# 2    26.0       3  female  26.0      0      0   7.9250        S   Third
# 3    35.0       1  female  35.0      1      0  53.1000        S   First
# 4    35.0       3    male  35.0      0      0   8.0500        S   Third
# ..    ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886  27.0       2    male  27.0      0      0  13.0000        S  Second
# 887  19.0       1  female  19.0      0      0  30.0000        S   First
# 888   NaN       3  female   NaN      1      2  23.4500        S   Third
# 889  26.0       1    male  26.0      0      0  30.0000        C   First
# 890  32.0       3    male  32.0      0      0   7.7500        Q   Third
#
#        WHO  ADULT_MALE DECK  EMBARK_TOWN ALIVE  ALONE
# ...

# %%
df.describe()
# Out:
#               AGE      PCLASS         AGE       SIBSP       PARCH        FARE
# count  714.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    29.699118    2.308642   29.699118    0.523008    0.381594   32.204208
# std     14.526497    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.420000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     28.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     38.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     80.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_num = df

# %%
df_num['age'].sum()
# Out:
# 21205.17

# %%
df_num['age'].mean()
# Out:
# 29.69911764705882

# %%
df_num['age'].median()
# Out:
# 28.0

# %%
df_num['age'].var() # 분산
# Out:
# 211.01912474630802

# %%
df_num['age'].std()
# Out:
# 14.526497332334042

# %%
df_num['fare'].kurt()
# Out:
# 33.39814088089868

# %%
df_num['fare'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_num['fare'].skew()
# Out:
# 4.787316519674893

# %%
df_num['fare'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_tmp = df

c1 = df_tmp['survived'] == 1
c2 = df_tmp['sex'] == 'female'
c3 = df_tmp['age'] >= 20
c4 = df_tmp['age'] < 30

cond = c1 & c2 & c3 & c4

df_tmp[cond].describe()

# df_tmp[cond].mean()
# Out:
#        survived     pclass        age      sibsp      parch        fare
# count      52.0  52.000000  52.000000  52.000000  52.000000   52.000000
# mean        1.0   2.000000  24.615385   0.480769   0.615385   48.354406
# std         0.0   0.766965   2.521701   0.779401   0.932083   66.199980
# min         1.0   1.000000  21.000000   0.000000   0.000000    7.250000
# 25%         1.0   1.000000  22.000000   0.000000   0.000000   12.139575
# 50%         1.0   2.000000  24.000000   0.000000   0.000000   21.629150
# 75%         1.0   3.000000  27.000000   1.000000   1.000000   57.500000
# max         1.0   3.000000  29.000000   3.000000   3.000000  263.000000

# %%
c1 = df_tmp['survived'] == 1
c2 = df_tmp['sex'] == 'female'
c3 = df_tmp['age'] >= 20
c4 = df_tmp['age'] < 30

cond = ~(c1 & c2 & c3 & c4)

df_tmp[cond].describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  839.000000  839.000000  662.000000  839.000000  839.000000  839.000000
# mean     0.345650    2.327771   30.098444    0.525626    0.367104   31.203242
# std      0.475863    0.836848   14.997875    1.120006    0.795971   48.360850
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   14.400000
# 75%      1.000000    3.000000   39.000000    1.000000    0.000000   30.597900
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df_tmp.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
